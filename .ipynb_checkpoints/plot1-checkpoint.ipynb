# %% [markdown]
# # Plot

# %% [markdown]
# Your information:
# - Student Name:
# - Student Number:

# %%
# %pip install plotly
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: plotly in /home/thijmen/.local/lib/python3.10/site-packages (5.15.0)
# Requirement already satisfied: packaging in /usr/lib/python3/dist-packages (from plotly) (21.3)
# Requirement already satisfied: tenacity>=6.2.0 in /home/thijmen/.local/lib/python3.10/site-packages (from plotly) (8.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly.graph_objs as go
import plotly.express as px
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('cleaned_data.csv')

df.head(n=10) # first 10 of the 17 rows
# Out:
#    Unnamed: 0      Country  Happiness Rank  Happiness Score  \
# 0         152  Afghanistan             153            3.575
# 1         311  Afghanistan             154            3.360
# 2         455  Afghanistan             141            3.794
# 3         614  Afghanistan             145            3.632
# 4         779  Afghanistan             154            3.203
# 5          94      Albania              95            4.959
# 6         266      Albania             109            4.655
# 7         423      Albania             109            4.644
# 8         581      Albania             112            4.586
# 9         732      Albania             107            4.719
#
#    Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                  0.319820  0.302850                  0.303350  0.234140
# 1                  0.382270  0.110370                  0.173440  0.164300
# 2                  0.401477  0.581543                  0.180747  0.106180
# 3                  0.332000  0.537000                  0.255000  0.085000
# 4                  0.350000  0.517000                  0.361000  0.000000
# 5                  0.878670  0.804340                  0.813250  0.357330
# 6                  0.955300  0.501630                  0.730070  0.318660
# 7                  0.996193  0.803685                  0.731160  0.381499
# 8                  0.916000  0.817000                  0.790000  0.419000
# 9                  0.947000  0.848000                  0.874000  0.383000
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual  Year
# 0                       0.097190    0.365100           1.952100  2015
# 1                       0.071120    0.312680           2.145580  2016
# 2                       0.061158    0.311871           2.150801  2017
# 3                       0.036000    0.191000           2.082827  2018
# 4                       0.025000    0.158000           2.082827  2019
# 5                       0.064130    0.142720           1.898940  2015
# 6                       0.053010    0.168400           1.928160  2016
# 7                       0.039864    0.201313           1.490442  2017
# 8                       0.032000    0.149000           1.772514  2018
# 9                       0.027000    0.178000           1.772514  2019

# %%
fig = px.area(df, x="Happiness Score", y="Freedom", color="Country", line_group="Country")
#fig.update_layout(xaxis=[tickvals="Year",ticktext="Year"])
fig.show()
# Out:
# <div>                            <div id="586dff7e-3f5a-478b-9ee0-b440309f0ca2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("586dff7e-3f5a-478b-9ee0-b440309f0ca2")) {                    Plotly.newPlot(                        "586dff7e-3f5a-478b-9ee0-b440309f0ca2",                        [{"fillpattern":{"shape":""},"hovertemplate":"Country=Afghanistan\u003cbr\u003eHappiness Score=%{x}\u003cbr\u003eFreedom=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Afghanistan","line":{"color":"#636efa"},"marker":{"symbol":"circle"},"mode":"lines","name":"Afghanistan","orientation":"v","showlegend":true,"stackgroup":"1","x":[3.575,3.36,3.79399991035461,3.632,3.203],"xaxis":"x","y":[0.23414,0.1643,0.106179520487785,0.085,0.0],"yaxis":"y","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"Country=Albania\u003cbr\u003eHappiness Score=%{x}\u003cbr\u003eFreedom=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Albania","line":{"color":"#EF553B"},"marker":{"symbol":"circle"},"mode":"lines","name":"Albania","orientation":"v","showlegend":true,"stackgroup":"1","x":[4.959,4.655,4.64400005340576,4.586,4.719],"xaxis":"x","y":[0.35733,0.31866,0.381498634815216,0.419,0.383],"yaxis":"y","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"Country=Algeria\u003cbr\u003eHappiness Score=%{x}\u003cbr\u003eFreedom=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Algeria","line":{"color":"#00cc96"},"marker":{"symbol":"circle"},"mode":"lines","name":"Algeria","orientation":"v","showlegend":true,"stackgroup":"1","x":[5.605,6.355,5.87200021743774,5.295,5.211],"xaxis":"x","y":[0.28579,0.21006,0.233335807919502,0.077,0.086],"yaxis":"y","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"Country=Angola\u003cbr\u003eHappiness Score=%{x}\u003cbr\u003eFreedom=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Angola","line":{"color":"#ab63fa"},"marker":{"symbol":"circle"},"mode":"lines","name":"Angola","orientation":"v","showlegend":true,"stackgroup":"1","x":[4.033,3.866,3.79500007629395,3.795],"xaxis":"x","y":[0.10384,0.00589,0.0,0.0],"yaxis":"y","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"Country=Argentina\u003cbr\u003eHappiness Score=%{x}\u003cbr\u003eFreedom=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Argentina","line":{"color":"#FFA15A"},"marker":{"symbol":"circle"},"mode":"lines","name":"Argentina","orientation":"v","showlegend":true,"stackgroup":"1","x":[6.574,6.65,6.59899997711182,6.388,6.086],"xaxis":"x","y":[0.44974,0.42284,0.494519203901291,0.57,0.471],"yaxis":"y","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"Country=Armenia\u003cbr\u003eHappiness Score=%{x}\u003cbr\u003eFreedom=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Armenia","line":{"color":"#19d3f3"},"marker":{"symbol":"circle"},"mode":"lines","name":"Armenia","orientation":"v","showlegend":true,"stackgroup":"1","x":[4.35,4.36,4.37599992752075,4.321,4.559],"xaxis":"x","y":[0.19847,0.14037,0.198303267359734,0.26,0.283],"yaxis":"y","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"Country=Australia\u003cbr\u003eHappiness Score=%{x}\u003cbr\u003eFreedom=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Australia","line":{"color":"#FF6692"},"marker":{"symbol":"circle"},"mode":"lines","name":"Australia","orientation":"v","showlegend":true,"stackgroup":"1","x":[7.284,7.313,7.28399991989136,7.272,7.228],"xaxis":"x","y":[0.65124,0.56837,0.601607382297516,0.647,0.557],"yaxis":"y","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"Country=Austria\u003cbr\u003eHappiness Score=%{x}\u003cbr\u003eFreedom=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Austria","line":{"color":"#B6E88 ...

# %%
fig = go.Figure()

#data = {
#    df["Country"]:df["Economy (GDP per Capita)"],
#}

#for key in data:
#    fig.add_trace(go.Bar(
#        name=key,
#        y=data[key],
#        x=np.cumsum(widths)-widths,
#        width=widths,
#        offset=0,
#        customdata=np.transpose([labels, widths*data[key]]),
#        texttemplate="%{y} x %{width} =<br>%{customdata[1]}",
#        textposition="inside",
#        textangle=0,
#        textfont_color="white",
#        hovertemplate="<br>".join([
#            "label: %{customdata[0]}",
#            "width: %{width}",
#            "height: %{y}",
#            "area: %{customdata[1]}",
#        ])
#    ))
fig.add_trace(go.Bar(
    x = df["Year"],
    y = df ["Year"]
))
#fig.update_xaxes(
#    tickvals=np.cumsum(widths)-widths/2,
#    ticktext= ["%s<br>%d" % (l, w) for l, w in zip(labels, widths)]
#)

fig.update_xaxes(range=[0,100])
fig.update_yaxes(range=[0,100])

fig.update_layout(
    title_text="Marimekko Chart",
    barmode="stack",
    uniformtext=dict(mode="hide", minsize=10),
)
# Out:
# <div>                            <div id="d0ae1586-05a1-4d28-8b85-e0a8f4d7f8d6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d0ae1586-05a1-4d28-8b85-e0a8f4d7f8d6")) {                    Plotly.newPlot(                        "d0ae1586-05a1-4d28-8b85-e0a8f4d7f8d6",                        [{"x":[2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2016,2017,2018,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2018,2019,2017,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2017,2018,2019,2015,2016,2017,2018,2019,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2019,2018,2019,2015,2016,2017,2018,2019,2015,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2016,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2016,2017,2018,2019,2016,2015,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2015,2016,2015,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,2015,2016,2018,2019,2017,2015,2016,2017,2018,2019,2015,2016,2017,2018,2019,201 ...

# %%
animals=df["Happiness Score"]

names = ["Happiness Score", "Economy (GDP per Capita)", "Family"] 
#"Health (Life Expectancy)", "Freedom",
#        "Trust (Government Corruption)", "Generosity", "Dystopia Residual"]

data = []
ydata = 3
countries = [i for i in df["Country"]]
countryset = set(countries)
countries = list(countryset)
for j in countries:
    bar = go.Bar(name=j, y = countries, x = names)
    data.append(bar)

fig = go.Figure(data=data)
# Change the bar mode
fig.update_layout(barmode='stack')
fig.show()
# Out:
# <div>                            <div id="c2804c18-5802-4227-b819-a675f71121bd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c2804c18-5802-4227-b819-a675f71121bd")) {                    Plotly.newPlot(                        "c2804c18-5802-4227-b819-a675f71121bd",                        [{"name":"Trinidad & Tobago","x":["Happiness Score","Economy (GDP per Capita)","Family"],"y":["Trinidad & Tobago","Sri Lanka","Serbia","Iceland","Cyprus","Bhutan","Moldova","Hong Kong","Zambia","Singapore","Canada","Central African Republic","Vietnam","Tajikistan","Turkmenistan","Jordan","Togo","Cameroon","Honduras","Angola","North Macedonia","Turkey","Yemen","Ivory Coast","Dominican Republic","Namibia","Uganda","Belarus","Colombia","Lebanon","Sudan","Iraq","Hungary","Palestinian Territories","Russia","Taiwan Province of China","South Africa","Botswana","South Sudan","South Korea","Denmark","Armenia","Cambodia","Latvia","Pakistan","Benin","Somalia","Italy","Gambia","Liberia","Chile","Rwanda","Chad","Lithuania","Greece","Egypt","United Arab Emirates","Argentina","Panama","Puerto Rico","Gabon","Guinea","Mauritania","India","El Salvador","Ecuador","Lesotho","Burkina Faso","China","Afghanistan","Luxembourg","Venezuela","Kazakhstan","Ireland","Finland","Malaysia","Georgia","Guatemala","New Zealand","Senegal","Mauritius","United States","Nepal","United Kingdom","Norway","Kuwait","Belgium","Portugal","Jamaica","Thailand","Indonesia","North Cyprus","Bosnia and Herzegovina","Myanmar","Tunisia","Australia","Philippines","Costa Rica","Somaliland Region","Nigeria","Mozambique","Malawi","Belize","Paraguay","Mali","Poland","Kosovo","Somaliland region","Germany","Kyrgyzstan","Suriname","Netherlands","Azerbaijan","Bahrain","Libya","Switzerland","Japan","Romania","Montenegro","Saudi Arabia","Slovakia","Oman","Bolivia","Swaziland","Madagascar","France","Peru","Northern Cyprus","Macedonia","Zimbabwe","Algeria","Kenya","Qatar","Congo (Brazzaville)","Trinidad and Tobago","Comoros","Taiwan","Bangladesh","Ukraine","Laos","Spain","Sweden","Albania","Morocco","Sierra Leone","Syria","Brazil","Czech Republic","Mexico","Congo (Kinshasa)","Malta","Haiti","Nicaragua","Niger","Mongolia","Iran","Bulgaria","Croatia","Hong Kong S.A.R., China","Israel","Ghana","Uzbekistan","Uruguay","Tanzania","Djibouti","Austria","Slovenia","Estonia","Burundi","Ethiopia"],"type":"bar"},{"name":"Sri Lanka","x":["Happiness Score","Economy (GDP per Capita)","Family"],"y":["Trinidad & Tobago","Sri Lanka","Serbia","Iceland","Cyprus","Bhutan","Moldova","Hong Kong","Zambia","Singapore","Canada","Central African Republic","Vietnam","Tajikistan","Turkmenistan","Jordan","Togo","Cameroon","Honduras","Angola","North Macedonia","Turkey","Yemen","Ivory Coast","Dominican Republic","Namibia","Uganda","Belarus","Colombia","Lebanon","Sudan","Iraq","Hungary","Palestinian Territories","Russia","Taiwan Province of China","South Africa","Botswana","South Sudan","South Korea","Denmark","Armenia","Cambodia","Latvia","Pakistan","Benin","Somalia","Italy","Gambia","Liberia","Chile","Rwanda","Chad","Lithuania","Greece","Egypt","United Arab Emirates","Argentina","Panama","Puerto Rico","Gabon","Guinea","Mauritania","India","El Salvador","Ecuador","Lesotho","Burkina Faso","China","Afghanistan","Luxembourg","Venezuela","Kazakhstan","Ireland","Finland","Malaysia","Georgia","Guatemala","New Zealand","Senegal","Mauritius","United States","Nepal","United Kingdom","Norway","Kuwait","Belgium","Portugal","Jamaica","Thailand","Indonesia","North Cyprus","Bosnia and Herzegovina","Myanmar","Tunisia","Australia","Philippines","Costa Rica","Somaliland Region","Nigeria","Mozambique","Malawi","Belize","Paraguay","Mali","Poland","Kosovo","Somaliland region","Germany","Kyrgyzstan","Suriname","Netherlands" ...

# %% [markdown]
# # Waarden van Afghanistan
#
# In de onderstaande grafiek zijn per jaar alle waarden van Afghanistan laten zien. Als voorbeeld nemen we Family. Door steeds te kijken naar het relatieve verschil tussen twee achtereenvolgende jaren, is te zien dat Family in dezelfde jaren stijgt en daalt als de Happiness Score. Dit kan erop wijzen dat Family invloed heeft op de uiteindelijke Happiness Score.

# %%
year = df.head(n=5)["Year"]
generosity = df.head(n=5)["Generosity"]
economy  = df.head(n=5)["Economy (GDP per Capita)"]
family  = df.head(n=5)["Family"]/2
health  = df.head(n=5)["Health (Life Expectancy)"]
freedom  = df.head(n=5)["Freedom"]
trust  = df.head(n=5)["Trust (Government Corruption)"]
dystopia  = df.head(n=5)["Dystopia Residual"]/10
rank = df.head(n=5)["Happiness Rank"] 
score = df.head(n=5)["Happiness Score"]/10

categories = ["Happiness Score/10","Generosity", "Economy (GDP per Capita)", "Family","Health (Life Expectancy)","Freedom",
              "Trust (Government Corruption)","Dystopia Residual / 10"] 


fig = go.Figure()
count = 0

for i in year:
    
    fig.add_trace(go.Scatterpolar(
          r=[score[count],generosity[count], economy[count], family[count],health[count],freedom[count],trust[count],dystopia[count]],
          theta=categories,
 #       fill = "toself",
          name=i
    ))
    count += 1

fig.update_layout(
    title = "Waarden van variabelen tussen jaren van Afghanistan",
  polar=dict(
    radialaxis=dict(
      visible=True,
      range=[0, 0.45]
    )),
  showlegend=True
)

fig.show()
# Out:
# <div>                            <div id="80acbb53-e3ab-4020-99dd-32feccdaaf24" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("80acbb53-e3ab-4020-99dd-32feccdaaf24")) {                    Plotly.newPlot(                        "80acbb53-e3ab-4020-99dd-32feccdaaf24",                        [{"name":"2015","r":[0.35750000000000004,0.3651,0.31982,0.151425,0.30335,0.23414,0.09719,0.19521],"theta":["Happiness Score\u002f10","Generosity","Economy (GDP per Capita)","Family","Health (Life Expectancy)","Freedom","Trust (Government Corruption)","Dystopia Residual \u002f 10"],"type":"scatterpolar"},{"name":"2016","r":[0.33599999999999997,0.31268,0.38227,0.055185,0.17344,0.1643,0.07112,0.21455799999999997],"theta":["Happiness Score\u002f10","Generosity","Economy (GDP per Capita)","Family","Health (Life Expectancy)","Freedom","Trust (Government Corruption)","Dystopia Residual \u002f 10"],"type":"scatterpolar"},{"name":"2017","r":[0.37939999103546096,0.311870932579041,0.401477217674255,0.2907716631889345,0.180746778845787,0.106179520487785,0.0611578300595284,0.215080118179321],"theta":["Happiness Score\u002f10","Generosity","Economy (GDP per Capita)","Family","Health (Life Expectancy)","Freedom","Trust (Government Corruption)","Dystopia Residual \u002f 10"],"type":"scatterpolar"},{"name":"2018","r":[0.3632,0.191,0.332,0.2685,0.255,0.085,0.036,0.20828270605977367],"theta":["Happiness Score\u002f10","Generosity","Economy (GDP per Capita)","Family","Health (Life Expectancy)","Freedom","Trust (Government Corruption)","Dystopia Residual \u002f 10"],"type":"scatterpolar"},{"name":"2019","r":[0.3203,0.158,0.35,0.2585,0.361,0.0,0.025,0.20828270605977367],"theta":["Happiness Score\u002f10","Generosity","Economy (GDP per Capita)","Family","Health (Life Expectancy)","Freedom","Trust (Government Corruption)","Dystopia Residual \u002f 10"],"type":"scatterpolar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333, ...

# %%
rank = df.head(n=5)["Happiness Rank"]
score = df.head(n=5)["Happiness Score"]

fig = go.Figure()
count = 0

for i in year:
    
    fig.add_trace(go.Scatterpolar(
          r=[rank[count],score[count]],
          theta=categories,
 #       fill = "toself",
          name=i
    ))
    count += 1
    
fig.update_layout(
    title = "Waarden van variabelen tussen jaren van Afghanistan",
  polar=dict(
    radialaxis=dict(
      visible=True,
      range=[0, 0.6]
    )),
  showlegend=True
)

fig.show()
# Out:
# <div>                            <div id="b01fa702-fca9-4c6d-857a-154c83de79fa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b01fa702-fca9-4c6d-857a-154c83de79fa")) {                    Plotly.newPlot(                        "b01fa702-fca9-4c6d-857a-154c83de79fa",                        [{"name":"2015","r":[153,3.575],"theta":["Generosity","Economy (GDP per Capita)","Family","Health (Life Expectancy)","Freedom","Trust (Government Corruption) * 5","Dystopia Residual \u002f 10"],"type":"scatterpolar"},{"name":"2016","r":[154,3.36],"theta":["Generosity","Economy (GDP per Capita)","Family","Health (Life Expectancy)","Freedom","Trust (Government Corruption) * 5","Dystopia Residual \u002f 10"],"type":"scatterpolar"},{"name":"2017","r":[141,3.79399991035461],"theta":["Generosity","Economy (GDP per Capita)","Family","Health (Life Expectancy)","Freedom","Trust (Government Corruption) * 5","Dystopia Residual \u002f 10"],"type":"scatterpolar"},{"name":"2018","r":[145,3.632],"theta":["Generosity","Economy (GDP per Capita)","Family","Health (Life Expectancy)","Freedom","Trust (Government Corruption) * 5","Dystopia Residual \u002f 10"],"type":"scatterpolar"},{"name":"2019","r":[154,3.203],"theta":["Generosity","Economy (GDP per Capita)","Family","Health (Life Expectancy)","Freedom","Trust (Government Corruption) * 5","Dystopia Residual \u002f 10"],"type":"scatterpolar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777 ...
